# %% [markdown]
# # import libraries

# %%
import pickle
import pandas as pd
import numpy as np
from tqdm import tqdm
from scipy.stats import pearsonr
from scipy.stats import ttest_ind as t
from sklearn.mixture import GaussianMixture
from sklearn.metrics.cluster import v_measure_score as v_score
X = np.array([[1, 2], [1, 4], [1, 0], [10, 666], [10, 4], [10, 0]])
gm = GaussianMixture(n_components=2, random_state=0).fit(X)
types = ['h1','h2']

# %%
aa ={'Switzerland':'mono','pencil':'mono','transistor':'mono','computer':'mono','door':'nn.figr.poly','potato':\
     'nn.plfd.poly','questions':'nv.poly','mistakes':'nv.poly','thought':'nv.poly','fish':'nn.anime.poly',\
     'salmon':'nn.anime.poly','like':'vprep.hom','tomatoes':'nn.plfd.poly','lamb':'nn.anime.poly',\
     'chicken':'nn.anime.poly','can':'nv.hom','power':'poly','bank':'nn.hom','rock':'nn.hom',\
     'books':'nv.hom','duck':'nn.anime.poly','dates':'nv.hom','even':'adjadv.hom',\
     'pupil':'nn.hom','tears':'nv.homg','moves':'nv.poly','book':'nv.hom','form':'nv.hom','watch':'nv.hom','wind':'nv.homg'} 
aa =pd.DataFrame.from_dict(aa,orient = 'index').reset_index().rename(columns = {'index':'target',0:'type'})
aa
# Out:
#          target           type
# 0   Switzerland           mono
# 1        pencil           mono
# 2    transistor           mono
# 3      computer           mono
# 4          door   nn.figr.poly
# 5        potato   nn.plfd.poly
# 6     questions        nv.poly
# 7      mistakes        nv.poly
# 8       thought        nv.poly
# 9          fish  nn.anime.poly
# 10       salmon  nn.anime.poly
# 11         like      vprep.hom
# 12     tomatoes   nn.plfd.poly
# 13         lamb  nn.anime.poly
# 14      chicken  nn.anime.poly
# 15          can         nv.hom
# 16        power           poly
# 17         bank         nn.hom
# 18         rock         nn.hom
# 19        books         nv.hom
# 20         duck  nn.anime.poly
# 21        dates         nv.hom
# 22         even     adjadv.hom
# 23        pupil         nn.hom
# 24        tears        nv.homg
# 25        moves        nv.poly
# 26         book         nv.hom
# 27         form         nv.hom
# 28        watch         nv.hom
# 29         wind        nv.homg

# %%
def euclidean(x,y):
    dist = np.linalg.norm(x-y)
    return dist.round(2)
def cos(x,y):
    dist = np.dot(x,y)/(np.linalg.norm(x)*np.linalg.norm(y))
    return dist.round(2)
#calculate the distance between two files
def single_type_word_dist(df,t):
    # t is the extraction type
    #four embedding is a dict key = c0 h0 c1 h1, val =  6 columns
    res = {}
    for word,dfx in df.groupby(by='target'):
        if word == 'went' or word =='line':
            continue
        dfa = dfx[dfx['file']=='1']
        dfb = dfx[dfx['file']=='2']
        x1 = dfa['tensors'].agg('mean')
        x2 = dfb['tensors'].agg('mean')
        #res[word] = euclidean(x1,x2)
        res[word] = cos(x1,x2)
    file_dis = pd.DataFrame.from_dict(res, orient='index',columns = [f'file_dist_{t}']).reset_index().rename(columns={"index": "target"})
    return file_dis
# calculate the ground truth distance between file
# input df contatin all embeddings of all target words
# extraction_type can be c0 h0 c1 h1
# output the distances of all target words
def all_types_of_dist(embed_dict,types=types):
    for t in types:
        delta_df = single_type_word_dist(embed_dict[t],t)
        if t == types[0]:
            df = delta_df
        else:
            df = pd.merge(df,delta_df, on='target')
    return df
# calculate l2 normalisation factors for each extraction type
def l2_normalisation_factors(embed_dict,types=types):
    norm_factors = pd.DataFrame(columns = ['target'] + [f'l2_{t}' for t in types])
    word_set = set()
    for t in types:
        a = []
        for word,group in embed_dict[t].groupby(by='target'):
            #exlude the werd words in the data set
            if word =='went' or word == 'line':
                continue
            word_set.add(word)
            a.append(np.linalg.norm(group['tensors'].apply('mean')))
        norm_factors[f'l2_{t}']=a
    norm_factors['target'] = list(word_set)
    return norm_factors
# Out:
#   File "/tmp/ipykernel_13042/4293052508.py", line 41
#     for word,group in embed_dict[t].groupby
#                                            ^
# SyntaxError: invalid syntax

# %%
# load pickled data
embed_dict = {}
for t in types:
    with open(f'contextual_embeddings/all_sent_{t}','rb') as f:
        embed_dict[t] = pickle.load(f)

# %%
embed_dict['h1'].head()
# Out:
#                                              tensors          labels file  \
# 0  [0.018521532, 0.045597155, 0.002335213, -0.058...     Looks like2    2
# 1  [0.07884548, 0.033203643, 0.01734861, -0.12496...  yourself like2    2
# 2  [0.0039849347, 0.016776048, 0.024410218, -0.02...   support like2    2
# 3  [0.11227927, 0.03317975, 0.001646313, -0.10016...        OS like2    2
# 4  [0.007854236, 0.0059105917, 0.009929255, -0.06...    around like2    2
#
#        prev target
# 0     Looks   like
# 1  yourself   like
# 2   support   like
# 3        OS   like
# 4    around   like

# %%
norm_factors = l2_normalisation_factors(embed_dict)
norm_factors
# Out:
#          target     l2_h1     l2_h2
# 0       chicken  2.436679  2.586743
# 1          lamb  2.746895  2.977511
# 2      mistakes  1.890011  2.198264
# 3          wind  2.066962  2.219100
# 4          bank  2.693521  2.875046
# 5   Switzerland  2.527750  3.696086
# 6          form  2.720585  3.577686
# 7      computer  3.013174  2.923898
# 8          book  2.651863  3.070725
# 9         moves  2.277530  3.279745
# 10         fish  2.800691  2.818152
# 11         duck  2.641267  3.459790
# 12        tears  2.191787  2.029681
# 13          can  2.736250  3.777138
# 14        power  2.358666  2.294240
# 15    questions  3.140015  2.402844
# 16        watch  2.335411  2.258063
# 17         rock  2.644316  3.172292
# 18     tomatoes  3.052633  4.188667
# 19        dates  2.572846  3.115314
# 20        books  2.337649  2.408792
# 21         even  2.681988  2.940146
# 22       salmon  2.795084  3.461234
# 23       potato  2.812057  3.668105
# 24   transistor  2.916636  3.106244
# 25         door  2.785728  2.290529
# 26        pupil  2.980957  3.300635
# 27       pencil  2.832435  3.684206
# 28      thought  2.384237  2.432895
# 29         like  2.790851  3.340504

# %%
all_types_dist_all_words = all_types_of_dist(embed_dict).set_index('target')
all_types_dist_all_words.head()
# Out:
#             file_dist_h1 file_dist_h2
# target
# Switzerland         0.94         0.91
# bank                 0.9         0.61
# book                0.58         0.44
# books               0.66         0.51
# can                  0.8         0.74

# %%
# fit 2 component Gaussian Mixture n times and return the result dist and acc dictionaries
# input random_seed,df is of one type [c0, h0, c1, h1], factor of the corresponding type, n_init in gmm 
# returns a df with target, dist and acc
# extraction_type is t
def gaussian_prediction_accuracy(random_seed,df,n,t='h1',metric='euclidean'):
    assert t in types
    #euclidean_dist = {}
    dist = {}
    v_of_all_targets = {}
    for word,group in df.groupby(by='target'):
        # exclude these two words
        if word == 'line' or word=='went':
            continue
        dfx = group.sort_values(by='file')
        truth = np.array(dfx['file'].apply(lambda x: int(x=='2')).to_list())
        data = np.array((dfx['tensors']).to_list())
        gm = GaussianMixture(n_components=2, random_state=random_seed,n_init=n).fit(data)
        means = gm.means_
        if metric == 'cosine':
            dist[word] = cos(means[0],means[1])
        if metric =='euclidean':
            dist[word] = euclidean(means[0],means[1])
        preds = gm.predict(data)
        # the accuracy approaches 0.5 for monoseme becuase it is a binary choice problem
        # we could have used v test here but there is no need.
        # v = v_score(preds,truth)
        # v_of_all_targets[word] = round(v,2)
        acc_1 = (np.sum(truth==preds)/len(truth)).round(2)
        acc_2 = (np.sum(truth!=preds)/len(truth)).round(2)
        if acc_1>= acc_2:
            v_of_all_targets[word] = acc_1
        else:
            v_of_all_targets[word] = acc_2
    return pd.DataFrame({'target':dist.keys(), f'dist_{t}':dist.values(), f'acc_{t}':v_of_all_targets.values()})

# %%
x = gaussian_prediction_accuracy(1,embed_dict['h1'],1,t='h1',metric='euclidean').sort_values(by='dist_h1')
x.head()
# Out:
#       target  dist_h1  acc_h1
# 27  tomatoes     1.13    0.76
# 10      duck     1.16    0.64
# 23      rock     1.21    0.70
# 24    salmon     1.24    0.67
# 20     power     1.28    0.77

# %%
# repeat the gaussian distance and clustering for n times and get the average
# extraction_type is t
def ngauss(n_random,df,n_init,t='h1',metric='euclidean'):
    # do the gaussian n_random times for an average value, return the result
    res = pd.DataFrame()
    for i in tqdm(range(n_random)):
        delta_df = gaussian_prediction_accuracy(i,df,n_init,t=t,metric=metric)
        if i==0:
            res = delta_df
        else:
            res[f'dist_{t}']+=delta_df[f'dist_{t}']
            res[f'acc_{t}']+= delta_df[f'acc_{t}']
    res[f'dist_{t}'] = res[f'dist_{t}'].apply(lambda x: (x/n_random)).round(2)
    res[f'acc_{t}'] = res[f'acc_{t}'].apply(lambda x: (x/n_random)).round(2)
    return res
# repeat the ngauss for [c0 h0 c1 h1], 4 times
def all_types_ngauss(n_random,embed_dict,n_init,types=types,metric='euclidean'):
    for t in types:
        if t==types[0]:
            res = ngauss(n_random,embed_dict[t],n_init,t=t,metric=metric)
        else:
            res = pd.DataFrame.merge(res,ngauss(n_random,embed_dict[t],n_init,t=t,metric = metric),on='target')
    return res

# %%
two_ng = all_types_ngauss(1,embed_dict,1)
# Out:
# 100%|█████████████████████████████████████████████| 1/1 [00:09<00:00,  9.01s/it]
# 100%|█████████████████████████████████████████████| 1/1 [00:08<00:00,  8.91s/it]

# %%
two_ng.sort_values(by='acc_h1')
# Out:
#          target  dist_h1  acc_h1  dist_h2  acc_h2
# 23         rock     1.21    0.52     2.24    0.61
# 19       potato     2.07    0.54     2.86    0.58
# 6      computer     1.76    0.54     2.54    0.56
# 24       salmon     1.12    0.54     2.06    0.71
# 20        power     1.19    0.54     2.66    0.62
# 18       pencil     1.28    0.55     2.32    0.55
# 27     tomatoes     1.09    0.56     2.31    0.68
# 0   Switzerland     2.33    0.60     1.76    0.66
# 12         fish     1.48    0.65     1.73    0.57
# 28   transistor     1.50    0.66     2.59    0.51
# 21        pupil     1.11    0.72     2.55    0.79
# 11         even     2.05    0.74     3.27    0.74
# 14         lamb     1.42    0.78     2.65    0.84
# 9          door     1.28    0.81     1.67    0.74
# 1          bank     1.47    0.83     3.14    0.92
# 10         duck     1.03    0.85     2.46    0.82
# 8        deduce     2.44    0.90     3.04    0.90
# 5       chicken     1.52    0.92     2.89    0.95
# 4           can     1.94    0.92     2.38    0.92
# 25        tears     1.97    0.93     3.02    0.98
# 26      thought     2.35    0.95     2.76    1.00
# 7         dates     2.14    0.95     3.53    1.00
# 15         like     2.02    0.97     2.11    0.98
# 29        watch     2.24    0.97     3.25    0.97
# 16     mistakes     2.54    0.98     3.63    1.00
# 3         books     1.89    0.98     2.60    0.95
# 22    questions     2.15    0.98     3.37    0.98
# 17        moves     2.28    1.00     2.88    1.00
# 13         form     2.03    1.00     3.04    0.60
# 2          book     1.94    1.00     2.76    1.00
# 30         wind     2.05    1.00     3.53    1.00

# %%
# new.sort_values(by ='file_dist_h1').to_csv('Results/4_distances')

# %%
# get the results
results= pd.DataFrame.merge(two_ng,all_types_dist_all_words,on='target')
results
# Out:
#          target  dist_h1  acc_h1  dist_h2  acc_h2  \
# 0   Switzerland     2.33    0.60     1.76    0.66
# 1          bank     1.47    0.83     3.14    0.92
# 2          book     1.94    1.00     2.76    1.00
# 3         books     1.89    0.98     2.60    0.95
# 4           can     1.94    0.92     2.38    0.92
# 5       chicken     1.52    0.92     2.89    0.95
# 6      computer     1.76    0.54     2.54    0.56
# 7         dates     2.14    0.95     3.53    1.00
# 8        deduce     2.44    0.90     3.04    0.90
# 9          door     1.28    0.81     1.67    0.74
# 10         duck     1.03    0.85     2.46    0.82
# 11         even     2.05    0.74     3.27    0.74
# 12         fish     1.48    0.65     1.73    0.57
# 13         form     2.03    1.00     3.04    0.60
# 14         lamb     1.42    0.78     2.65    0.84
# 15         like     2.02    0.97     2.11    0.98
# 16     mistakes     2.54    0.98     3.63    1.00
# 17        moves     2.28    1.00     2.88    1.00
# 18       pencil     1.28    0.55     2.32    0.55
# 19       potato     2.07    0.54     2.86    0.58
# 20        power     1.19    0.54     2.66    0.62
# 21        pupil     1.11    0.72     2.55    0.79
# 22    questions     2.15    0.98     3.37    0.98
# 23         rock     1.21    0.52     2.24    0.61
# 24       salmon     1.12    0.54     2.06    0.71
# 25        tears     1.97    0.93     3.02    0.98
# 26      thought     2.35    0.95     2.76    1.00
# 27     tomatoes     1.09    0.56     2.31    0.68
# 28   transistor     1.50    0.66     2.59    0.51
# 29        watch     2.24    0.97     3.25    0.97
# 30         wind     2.05    1.00     3.53    1.00
#
#                                          file_dist_h1  \
# 0                                                0.94
# 1                                                 0.9
# 2                                                0.58
# 3                                                0.66
# 4                                                 0.8
# 5                                                0.86
# 6                                                0.98
# 7                                                 0.8
# 8   [nan, nan, nan, nan, nan, nan, nan, nan, nan, ...
# 9                                                0.93
# 10                                               0.91
# 11                                               0.78
# 12                                               0.97
# 13                                               0.66
# 14                                               0.92
# 15                                               0.72
# 16                                               0.73
# 17                                               0.62
# 18                                               0.96
# 19                                               0.96
# 20                                                0.9
# 21                                                0.9
# 22                                               0.74
# 23                                               0.94
# 24                                               0.95
# 25                                                0.8
# 26                                                0.7
# 27                                               0.96
# 28                                               0.96
# 29                                               0.65
# 30                                               0.76
#
#                                          file_dist_h2
# 0                                                0.91
# 1                                                0.61
# 2                                                0.44
# 3                                                0.51
# 4                                                0.74
# 5                                                0.76
# 6                                                0.97
# 7                                                 0.5
# 8   [nan, nan, nan, nan, nan, nan, nan, nan, nan, ...
# 9                                                0.88
# 10                                                0.8
# 11                                               0.58
# 12                                               0.88
# 13                                                0.3
# 14                                               0.84
# 15                                               0.68
# 16                                               0.28
# 17                                               0.43
# 18                                               0.91
# 19                                               0.88
# 20                                               0.76
# 21                                                0.6
# 22                                               0.54
# 23                                               0.78
# 24                                               0.85
# 25                                               0.64
# 26                                               0.47
# 27                                               0.89
# 28                                               0.95
# 29                                               0.38
# 30                                               0.56

# %%
# apply pearson's r to dis and acc
corr = {}
p = {}
for i in types:
    a = pearsonr(results[f'dist_{i}'],results[f'acc_{i}'])
#     b = pearsonr(results[f'dist_{i}'],results[f'file_dist_{i}'])
    c = pearsonr(results[f'file_dist_{i}'],results[f'acc_{i}'])
    corr[i] = [a[0],a[1]]
    p[i] = [c[0],c[1]]
corr = pd.DataFrame.from_dict(corr,orient='index',columns =['corr_dist_acc','p_dist_acc']).reset_index()
p = pd.DataFrame.from_dict(p,orient='index', columns =['corr_file_dist_acc','p_file_dist_acc']).reset_index()
corr_p = pd.DataFrame.merge(corr,p, on = 'index').rename(columns = {'index':'types'}).set_index('types')
corr_p
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_13042/2876778461.py in <module>
#       5     a = pearsonr(results[f'dist_{i}'],results[f'acc_{i}'])
#       6 #     b = pearsonr(results[f'dist_{i}'],results[f'file_dist_{i}'])
# ----> 7     c = pearsonr(results[f'file_dist_{i}'],results[f'acc_{i}'])
#       8     corr[i] = [a[0],a[1]]
#       9     p[i] = [c[0],c[1]]
#
# ~/.cache/pypoetry/virtualenvs/polysemy-EBh2Gjjb-py3.7/lib/python3.7/site-packages/scipy/stats/stats.py in pearsonr(x, y)
#    4020
#    4021     # If an input is constant, the correlation coefficient is not defined.
# -> 4022     if (x == x[0]).all() or (y == y[0]).all():
#    4023         warnings.warn(PearsonRConstantInputWarning())
#    4024         return np.nan, np.nan
#
# AttributeError: 'bool' object has no attribute 'all'

# %%
results.sort_values(by='acc_h0') #.drop(['acc_h0','acc_c1','acc_c0','acc_h1',],axis=1)
comparison = results[['target','acc_c0','acc_c1','acc_h0','acc_h1','dist_c0','dist_c1','dist_h0','dist_h1','file_dist_c0','file_dist_h0','file_dist_c1','file_dist_h1',]]
comparison.sort_values(by='acc_c1').reset_index().drop(['index'],axis=1)
# Out:
#          target  acc_c0  acc_c1  acc_h0  acc_h1  dist_c0  dist_c1  dist_h0  \
# 0        potato    0.50    0.50    0.54    0.58     4.93     5.06     2.07
# 1      computer    0.54    0.51    0.54    0.56     2.35     5.16     1.76
# 2          fish    0.65    0.52    0.65    0.57     5.08     3.35     1.48
# 3          rock    0.52    0.55    0.52    0.61     4.23     6.92     1.21
# 4        pencil    0.50    0.55    0.55    0.55     4.85     5.16     1.28
# 5   Switzerland    0.69    0.57    0.60    0.66     4.91     5.30     2.33
# 6    transistor    0.66    0.57    0.66    0.51     4.94     8.38     1.50
# 7         power    0.59    0.62    0.54    0.62     5.05     6.08     1.19
# 8      tomatoes    0.63    0.63    0.56    0.68     4.95     6.21     1.09
# 9          door    0.79    0.64    0.81    0.74     4.40     4.05     1.28
# 10       salmon    0.54    0.67    0.54    0.71     4.57     5.64     1.12
# 11         duck    0.74    0.82    0.85    0.82     4.16     6.29     1.03
# 12         lamb    0.84    0.84    0.78    0.84     4.61     5.83     1.42
# 13        pupil    0.69    0.87    0.72    0.79     3.88     6.38     1.11
# 14         bank    0.83    0.88    0.83    0.92     4.03     6.85     1.47
# 15          can    0.97    0.92    0.92    0.92     5.79     6.56     1.94
# 16         like    0.92    0.95    0.97    0.98     6.07     4.98     2.02
# 17      chicken    0.95    0.95    0.92    0.95     5.25     6.04     1.52
# 18        books    0.95    0.95    0.98    0.95     6.08     7.20     1.89
# 19         book    1.00    0.95    1.00    1.00     6.59     7.65     1.94
# 20        watch    0.97    0.97    0.97    0.97     6.58     9.27     2.24
# 21         even    1.00    0.97    0.74    0.74     5.85     7.65     2.05
# 22     mistakes    0.98    0.98    0.98    1.00     6.52     9.88     2.54
# 23    questions    0.98    0.98    0.98    0.98     6.33     8.49     2.15
# 24        tears    0.98    0.98    0.93    0.98     5.66     6.93     1.97
# 25      thought    0.93    0.98    0.95    1.00     6.29     7.35     2.35
# 26         form    0.56    1.00    1.00    0.60     4.34     8.70     2.03
# 27        dates    0.87    1.00    0.95    1.00     5.21     7.48     2.14
# 28        moves    1.00    1.00    1.00    1.00     6.17     7.38     2.28
# 29         wind    0.77    1.00    1.00    1.00     5.92     7.91     2.05
#
#     dist_h1  file_dist_c0  file_dist_h0  file_dist_c1  file_dist_h1
# 0      2.86          0.97          0.96          0.90          0.88
# 1      2.54          0.99          0.98          0.97          0.97
# 2      1.73          0.97          0.97          0.90          0.88
# 3      2.24          0.96          0.94          0.80          0.78
# 4      2.32          0.97          0.96          0.94          0.91
# 5      1.76          0.97          0.94          0.96          0.91
# 6      2.59          0.97          0.96          0.96          0.95
# 7      2.66          0.93          0.90          0.82          0.76
# 8      2.31          0.97          0.96          0.93          0.89
# 9      1.67          0.95          0.93          0.92          0.88
# 10     2.06          0.96          0.95          0.88          0.85
# 11     2.46          0.93          0.91          0.79          0.80
# 12     2.65          0.93          0.92          0.87          0.84
# 13     2.55          0.94          0.90          0.66          0.60
# 14     3.14          0.94          0.90          0.73          0.61
# 15     2.38          0.87          0.80          0.74          0.74
# 16     2.11          0.84          0.72          0.77          0.68
# 17     2.89          0.89          0.86          0.79          0.76
# 18     2.60          0.84          0.66          0.58          0.51
# 19     2.76          0.78          0.58          0.46          0.44
# 20     3.25          0.82          0.65          0.31          0.38
# 21     3.27          0.84          0.78          0.62          0.58
# 22     3.63          0.88          0.73          0.37          0.28
# 23     3.37          0.87          0.74          0.52          0.54
# 24     3.02          0.88          0.80          0.68          0.64
# 25     2.76          0.86          0.70          0.54          0.47
# 26     3.04          0.81          0.66          0.36          0.30
# 27     3.53          0.91          0.80          0.61          0.50
# 28     2.88          0.85          0.62          0.59          0.43
# 29     3.53          0.82          0.76          0.54          0.56

# %%
# t(comparison['acc_h0'],comparison['acc_h1'])

# %%
# l2 normalise the four ngauss results
# df contains only distantces
def normalise_results(df,norm_factors,types = types):
    new = df.copy()
    for t in types:
        new[f'dist_{t}'] =  (new[f'dist_{t}']/norm_factors[f'l2_{t}']).round(2)
        new[f'file_dist_{t}'] =  (new[f'file_dist_{t}']/norm_factors[f'l2_{t}']).round(2)
    return new

# %%
dists = results[['target','dist_c0','dist_c1','dist_h0','dist_h1','file_dist_c0','file_dist_c1','file_dist_h0','file_dist_h1',]]

# %%
dists = pd.merge(dists,aa,on='target')
# dists['sort'] = dists['type'].apply(lambda x: x.split('.')[-1])

# %%
dists.sort_values(by='dist_h1')[['target','type','dist_c0','dist_c1','dist_h0','dist_h1']]
# Out:
#          target           type  dist_c0  dist_c1  dist_h0  dist_h1
# 8          door   nn.figr.poly     4.40     4.05     1.28     1.67
# 11         fish  nn.anime.poly     5.08     3.35     1.48     1.73
# 0   Switzerland           mono     4.91     5.30     2.33     1.76
# 23       salmon  nn.anime.poly     4.57     5.64     1.12     2.06
# 14         like      vprep.hom     6.07     4.98     2.02     2.11
# 22         rock         nn.hom     4.23     6.92     1.21     2.24
# 26     tomatoes   nn.plfd.poly     4.95     6.21     1.09     2.31
# 17       pencil           mono     4.85     5.16     1.28     2.32
# 4           can         nv.hom     5.79     6.56     1.94     2.38
# 9          duck  nn.anime.poly     4.16     6.29     1.03     2.46
# 6      computer           mono     2.35     5.16     1.76     2.54
# 20        pupil         nn.hom     3.88     6.38     1.11     2.55
# 27   transistor           mono     4.94     8.38     1.50     2.59
# 3         books         nv.hom     6.08     7.20     1.89     2.60
# 13         lamb  nn.anime.poly     4.61     5.83     1.42     2.65
# 19        power           poly     5.05     6.08     1.19     2.66
# 2          book         nv.hom     6.59     7.65     1.94     2.76
# 25      thought        nv.poly     6.29     7.35     2.35     2.76
# 18       potato   nn.plfd.poly     4.93     5.06     2.07     2.86
# 16        moves        nv.poly     6.17     7.38     2.28     2.88
# 5       chicken  nn.anime.poly     5.25     6.04     1.52     2.89
# 24        tears        nv.homg     5.66     6.93     1.97     3.02
# 12         form         nv.hom     4.34     8.70     2.03     3.04
# 1          bank         nn.hom     4.03     6.85     1.47     3.14
# 28        watch         nv.hom     6.58     9.27     2.24     3.25
# 10         even     adjadv.hom     5.85     7.65     2.05     3.27
# 21    questions        nv.poly     6.33     8.49     2.15     3.37
# 7         dates         nv.hom     5.21     7.48     2.14     3.53
# 29         wind        nv.homg     5.92     7.91     2.05     3.53
# 15     mistakes        nv.poly     6.52     9.88     2.54     3.63

# %%
a = normalise_results(dists,norm_factors)

# %%
a[['target','dist_c0','dist_c1','dist_h0','dist_h1']].sort_values(by='dist_h1')
# Out:
#          target  dist_c0  dist_c1  dist_h0  dist_h1
# 11         fish     0.48     0.40     0.56     0.50
# 8          door     0.44     0.51     0.48     0.54
# 23       salmon     0.41     0.67     0.40     0.56
# 22         rock     0.41     0.82     0.43     0.65
# 0   Switzerland     0.48     0.67     0.96     0.68
# 18       potato     0.46     0.54     0.68     0.68
# 27   transistor     0.48     0.97     0.53     0.70
# 26     tomatoes     0.43     0.62     0.37     0.70
# 13         lamb     0.46     0.66     0.52     0.70
# 6      computer     0.21     0.66     0.65     0.71
# 17       pencil     0.49     0.65     0.48     0.73
# 9          duck     0.46     0.81     0.45     0.75
# 5       chicken     0.51     0.72     0.60     0.78
# 4           can     0.54     0.85     0.72     0.83
# 19        power     0.48     0.77     0.46     0.85
# 14         like     0.67     0.73     0.86     0.92
# 24        tears     0.51     0.90     0.68     0.97
# 1          bank     0.39     0.88     0.54     1.05
# 20        pupil     0.38     0.97     0.47     1.06
# 29         wind     0.58     1.08     0.73     1.06
# 21    questions     0.55     1.17     0.80     1.15
# 10         even     0.58     1.01     0.73     1.16
# 3         books     0.59     1.07     0.91     1.17
# 25      thought     0.54     1.11     0.84     1.20
# 7         dates     0.45     0.99     0.71     1.21
# 2          book     0.71     1.22     1.03     1.26
# 16        moves     0.56     1.02     0.98     1.28
# 28        watch     0.64     1.45     0.94     1.34
# 12         form     0.44     1.40     0.93     1.50
# 15     mistakes     0.52     1.37     0.81     1.51

# %%
(norm_factors[['target','l2_c0','l2_c1','l2_h0','l2_h1',]]).round(2).sort_values(by='target')
# Out:
#          target  l2_c0  l2_c1  l2_h0  l2_h1
# 3   Switzerland  10.38   6.71   2.07   2.22
# 6          bank  10.94   7.81   2.72   3.58
# 28         book  10.24   6.38   2.38   2.43
# 4         books  10.68   7.68   2.69   2.88
# 9           can   9.12   7.78   2.28   3.28
# 19      chicken  10.44   7.91   2.57   3.12
# 23     computer  11.04   8.43   2.81   3.67
# 0         dates  10.12   7.95   2.44   2.59
# 12         door   9.86   6.22   2.19   2.03
# 24         duck  11.10   7.73   2.92   3.11
# 26         even  11.52   9.96   2.98   3.30
# 11         fish  10.59   8.43   2.64   3.46
# 15         form  12.56   7.21   3.14   2.40
# 14         lamb   9.08   6.82   2.36   2.29
# 2          like   9.23   6.27   1.89   2.20
# 13     mistakes  10.03   8.80   2.74   3.78
# 29        moves  10.21   7.29   2.79   3.34
# 8        pencil   9.99   7.93   2.65   3.07
# 10       potato  10.02   7.58   2.80   2.82
# 27        power  10.25   8.65   2.83   3.68
# 16        pupil  10.96   7.25   2.34   2.26
# 22    questions  10.33   8.41   2.80   3.46
# 21         rock  11.46   7.25   2.68   2.94
# 25       salmon  11.54   6.61   2.79   2.29
# 18        tears  10.64   9.33   3.05   4.19
# 1       thought  10.26   7.78   2.75   2.98
# 17     tomatoes   9.98   7.98   2.64   3.17
# 20   transistor  10.19   6.55   2.34   2.41
# 7         watch  11.49   7.58   3.01   2.92
# 5          wind  10.33   8.34   2.53   3.70

# %%
5.3/2.0
# Out:
# 2.65
